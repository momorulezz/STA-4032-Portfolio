# %% [markdown]
# <a href="https://colab.research.google.com/github/momorulezz/STA-4032-Portfolio/blob/main/Lab%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Monte Carlo

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Creates 100 different numbers between -3 and 3
x = np.linspace(-3,3,100)

# %%
y = x**2 + 2

# %%
plt.plot(x,y)

# %% [markdown]
# $f(x) = x^2 + 2$
#
# $Area = \int_a^bf(x) dx$
#
# $= \int_a^b (x^2+2) dx$
#
# $= \left.\frac{x^3}{3}+2x\right\vert_1^2$
#
# $= (\frac{8}{3}+4) - (\frac{1}{3}+2)$
#
# $= \frac{13}{3}$

# %%
13/3
# Out:
# 4.333333333333333

# %% [markdown]
# To integrate the function $f(x)$ over the interval $[a,b]$ we
#
# [1] find some value $M$ such that $f(x) < M$ over the interval $[a,b]$
#
# [2] select a random number $x$ from a uniform distribution over the interval $[a,b]$
#
# [3] select a random number y from a uniform distribution over the interval $[0,M]$
#
# [4] determine if $y > f(x)$ or $y ≤ f(x)$
#
# [5] repeat this process $N$ times, keeping track of the number of times $y ≤ f(x)$ or under the curve, successes $S$.
#
# The estimated probability of success is then:

# %% [markdown]
# $\frac{S}{N}=\frac{\text{Area under curve}}{\text{Total area inside rectangle}} = \frac{\int_a^bf(x)dx}{M(b-a)}$

# %% [markdown]
# $\int_a^bf(x)dx = M(b-a)\frac{S}{N}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function g(x)
def g(x):
    return 3*x**3 - 6*x**2 + 3*x - 2

# Generate x values
x = np.linspace(-1, 2, 500)

# Generate y values
y = g(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='$g(x) = 3x^3 - 6x^2 + 3x - 2$')

# Shade the area under the curve
plt.fill_between(x, y, color='skyblue', alpha=0.4)

# Adding labels and title
plt.title('Area under $g(x)$ over [-1, 2]')
plt.xlabel('$x$')
plt.ylabel('$g(x)$')
plt.legend()

# Show plot
plt.grid(True)
plt.show()
a, b = -1, 2
x = np.linspace(a, b, 10000)
M = max(g(x))

# Number of trials N
N = 100000

# Monte Carlo Integration
successes = 0
for _ in range(N):
    x = np.random.uniform(a, b)
    y = np.random.uniform(0, M)
    if y <= g(x):
        successes += 1

# Estimate the integral
estimated_integral = (successes / N) * (b - a) * M
estimated_integral
# Out:
# 0.65364

# %%
#simpler way; I tried triple integration
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from sympy import symbols, integrate

# %%
#defines which variables we will use
x,y,=symbols('x y')

# %%
#function for integration
f=x**2+2**y

# %%
Q=integrate(f,x)
Q
# Out:
# 2**y*x + x**3/3

# %%
L=integrate(f,x)
W=integrate(f,y)

# %%
L
# Out:
# 2**y*x + x**3/3

# %%
W
# Out:
# 2**y/log(2) + x**2*y

# %%
a,b,c,d= 1,4,1,2

# %%
# Assuming you want to integrate with respect to x from a to b
# and with respect to y from c to d:
definite_result = integrate(integrate(f, (x, a, b)), (y, c, d))
definite_result
# Out:
# 6/log(2) + 21

# %%
x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(x, y)
f = X**2 + 2**Y
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, f, cmap='viridis', edgecolor='none')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(x, y) = x^2 + 2^y')
ax.set_title('Surface Plot of f(x, y) = x^2 + 2^y')
plt.colorbar(surf)  # Add a color bar to indicate the values of Z
plt.show()

# %%
M = 10

# %%
a = 1
b = 2

# %%
x = a + (b-a)*np.random.random()

# %%
x
# Out:
# 1.36450759911944

# %%
y = M*np.random.random()

# %%
x,y,f(x)
# Out:
# (1.36450759911944, 0.11123146124385919, 3.8618809880546983)

# %%
y < f(x)
# Out:
# True

# %%
N = 100_000
S = 0
for i in range(N):

    x = a + (b-a)*np.random.random()
    y = M*np.random.random()

    S += (y < f(x))

M*(b-a)*(S/N)
# Out:
# 4.3307

# %%
def f(x):
    y = x**2 + 2
    return y

# %%
def monte_carlo_integrate(f,a,b,N):

    N = 10000000
    S = 0
    for i in range(N):

        x = a + (b-a)*np.random.random()
        y = M*np.random.random()

        S += (y < f(x))

    return M*(b-a)*(S/N)

# %%
monte_carlo_integrate(f,1,2,1000)
# Out:
# 4.3324560000000005

# %%
from sympy import *

# %%
x = Symbol('x')

# %%
x
# Out:
# x

# %%
integrate(x**2 + 2, (x,1,2))
# Out:
# 13/3

# %%
13/3
# Out:
# 4.333333333333333

# %%
integrate(x**3 + 3, (x,1,2))
# Out:
# 27/4

# %%
27/4
# Out:
# 6.75

# %%
x = 0

# %%
def f(x):
    y = x**3 + 3
    return y

# %%
monte_carlo_integrate(f,1,2,1000)
# Out:
# 6.745622

# %%
N = 2000
S = 0
Z = np.zeros(N,)
for i in range(1,N):

    x = a + (b-a)*np.random.random()
    y = M*np.random.random()

    S += (y < f(x))

    Z[i] = M*(b-a)*(S/i)

# %%
plt.plot(Z)
plt.plot(6.75*np.ones(Z.shape))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, integrate

# Define a general function for Monte Carlo integration
#first set the variables that will need to be called/defined
def monte_carlo_integrate(func, a, b, N, M):
    S = 0
    for _ in range(N):
        x = a + (b - a) * np.random.random()
        y = M * np.random.random()
        if y < func(x):
            S += 1
    return M * (b - a) * (S / N)

# Define the functions to be integrated
def f1(x):
    return x**3 + 7

def f2(x):
    return x**5 + 12

# Calculate exact and estimated areas
def calculate_areas(func, a, b, N, M):
    x_sym = Symbol('x')
    #evalf() calls on result of integration and provides a numerical approximation of integral's value.
    exact_area = integrate(func(x_sym), (x_sym, a, b)).evalf()
    estimated_area = monte_carlo_integrate(func, a, b, N, M)
    return exact_area, estimated_area

# Plotting function
def plot_function(func, title, a=-3, b=3):
    x = np.linspace(a, b, 100)
    y = func(x)
    plt.plot(x, y, label=title)
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend()
    plt.show()

# Plot the functions
plot_function(f1, "f(x)=x^3 + 7")
plot_function(f2, "f(x) = x^5 + 12")

# Calculate and print areas
exact_area_f1, estimated_area_f1 = calculate_areas(f1, 1, 2, 100000, 20)
exact_area_f2, estimated_area_f2 = calculate_areas(f2, 1, 2, 1000000, 20)

print("Exact Area under f1:", exact_area_f1)
print("Estimated Area under f1:", estimated_area_f1)
print("Exact Area under f2:", exact_area_f2)
print("Estimated Area under f2:", estimated_area_f2)
# Out:
# Exact Area under f1: 10.7500000000000
# Estimated Area under f1: 10.799399999999999
# Exact Area under f2: 22.5000000000000
# Estimated Area under f2: 17.7271

# %% [markdown]
# # Visualization

# %%
#Lessons Learned:
#1. Integral's estimation is based on ratio of number of green points to total number of points scattered across [a,b] on x-axis and [0,m] on y-axis
#2. The red areas help define total area, indirectly contribute
#increasing N leads to a more accurate stimate of integral.
# Function to plot points for Monte Carlo integration
#func is the function that we will integrate
#a,b are lower and upper bounds
#M is max Y value
#N is random number of points generated
def plot_monte_carlo(func, a, b, M, N):
  #x_points generates N random x values within interval [a,b]
  #b-a stretches our range from, for example, 0 to 1, to 0 to 3. We do not want our numbers to start from 0, though, we want them to start at a. This is why we add a; this makes it so that the range is from [2,5], or whatever the range we decide.
    x_points = a + (b - a) * np.random.random(N)
    #generates N random y-values beyweem [0,M]
    y_points = M * np.random.random(N)
    #Boolean array indicating whether a randomly generated points falls below func(x)
    below = y_points < func(x_points)
    #creates a boolean array for points that do not fall below function. Negates below array
    above = np.invert(below)

    # Plotting the function
    x = np.linspace(a - 1, b + 1, 400)
    y = func(x)
    plt.plot(x, y, label="f(x)", color='black')

    # Plotting the points
    plt.scatter(x_points[below], y_points[below], color='green', label='Points below f(x)')
    plt.scatter(x_points[above], y_points[above], color='red', label='Points above f(x)')

    # Setting up the plot limits and labels
    plt.xlim(a - 1, b + 1)
    plt.ylim(0, M)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Monte Carlo Integration Visualization")
    plt.legend()

    plt.show()

# Function to be integrated
def f(x):
    return x**2 + 2

# Parameters for Monte Carlo Integration
a, b, M, N = 1, 2, 20, 1000

# Plotting the Monte Carlo Integration
plot_monte_carlo(f, a, b, M, N)

# %%
# Function for Monte Carlo Integration
def monte_carlo_integrate(func, a, b, N, M):
    S = 0
    for _ in range(N):
        x = a + (b - a) * np.random.random()
        y = M * np.random.random()
        if y < func(x):
            S += 1
    return M * (b - a) * (S / N)

# Function to be integrated
def f(x):
    return x**2 + 2

# Parameters
a, b, M = 1, 2, 20
iterations = np.logspace(1, 6, 100, dtype=int)  # Using logarithmically spaced iterations for smoother curve
estimated_areas = []

# Calculate estimated areas for different numbers of iterations
for N in iterations:
    estimated_area = monte_carlo_integrate(f, a, b, N, M)
    estimated_areas.append(estimated_area)

# Plotting convergence
plt.figure(figsize=(10, 6))
plt.plot(iterations, estimated_areas, color='blue')
plt.xscale('log')
plt.xlabel('Number of Iterations (log scale)')
plt.ylabel('Estimated Area')
plt.title('Convergence of Monte Carlo Integration')
plt.grid(True)
plt.show()
